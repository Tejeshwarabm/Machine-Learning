# %% [markdown]
# <a href="https://colab.research.google.com/github/Tejeshwarabm/Machine-Learning/blob/master/Seaborn_Demo.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib as mpl
# Out:
# /usr/local/lib/python3.6/dist-packages/statsmodels/tools/_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm

# %%
# Ignore warnings

import warnings

warnings.simplefilter(action = "ignore", category = FutureWarning)

# %%
from google.colab import drive
drive.mount('/gdrive')

# %%
with open('/gdrive/My Drive/foo.txt', 'w') as f:
  f.write('Hello Google Drive!')
# !cat '/gdrive/My Drive/foo.txt'

# %%
pokemon = pd.read_csv('/gdrive/My Drive/colab/pokemon.csv')

# %%
pokemon.head()
# Out:
#    #                   Name Type 1  ... Speed  Generation  Legendary
# 0  1              Bulbasaur  Grass  ...    45           1      False
# 1  2                Ivysaur  Grass  ...    60           1      False
# 2  3               Venusaur  Grass  ...    80           1      False
# 3  3  VenusaurMega Venusaur  Grass  ...    80           1      False
# 4  4             Charmander   Fire  ...    65           1      False
#
# [5 rows x 13 columns]

# %%
tips = sns.load_dataset('tips')

# %%
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
warnings.simplefilter(action = "ignore", category = UserWarning)

print(sns.get_dataset_names())
# Out:
# ['anagrams', 'anscombe', 'attention', 'brain_networks', 'car_crashes', 'diamonds', 'dots', 'exercise', 'flights', 'fmri', 'gammas', 'geyser', 'iris', 'mpg', 'penguins', 'planets', 'tips', 'titanic']

# %%
sns.set()

# %%
sns.distplot(tips['total_bill'])
plt.show()

# %%
sns.distplot(tips['total_bill'], kde=False, rug=True)

# %%
sns.distplot(tips['total_bill'], hist=False)

# %%
sns.jointplot(x="total_bill", y="tip", data=tips)
plt.show()

# %%
sns.scatterplot(x="total_bill", y="tip", data=tips)

# %%
sns.set_style("ticks")
sns.pairplot(tips)
plt.show()

# %%
sns.stripplot(x="day", y="total_bill", data=tips)

# %%
sns.swarmplot(x='day', y="total_bill", data=tips)

# %%
sns.boxenplot(x=tips['total_bill'])

# %%
sns.boxplot(x=tips['tip'])

# %%
sns.boxplot(x='day', y='total_bill', data=tips)

# %%
sns.violinplot(x='day', y='total_bill', data=tips)

# %%
sns.barplot(x='day', y='total_bill', data=tips)

# %%
sns.pointplot(x='time', y='total_bill', data=tips)

# %%
sns.pointplot(x='day', y='tip', hue='smoker', data=tips)

# %%
sns.regplot(x="total_bill", y="tip", data=tips)

# %%
sns.lmplot(x="total_bill", y="tip", hue="smoker", data=tips)

# %%
sns.residplot(x='total_bill', y='tip', data=tips)

# %%
df1 = tips[['total_bill', 'tip', 'size']]
sns.clustermap(df1)

# %%
g = sns.FacetGrid(tips, col='time', row='smoker')
g = g.map(plt.hist, 'total_bill')
plt.show()

# %%
g = sns.PairGrid(tips)
g = g.map(plt.scatter)

# %%
g = sns.PairGrid(tips)
g = g.map_diag(plt.hist)
g = g.map_offdiag(plt.scatter)

# %%
g = sns.JointGrid(x='total_bill', y='tip', data=tips)
g = g.plot(sns.regplot, sns.distplot)
